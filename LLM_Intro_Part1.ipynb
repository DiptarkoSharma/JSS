# %%
# !pip install OpenAI
# !pip install langchain
# !pip install langchain_community
# !pip install Cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 41.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 57.0 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['COHERE_API_KEY'] = 'YOUR _COHERE_KEY'
#os.environ['OPEN_AI_API_KEY']='YOUR KEY'
import warnings
warnings.filterwarnings('ignore')

# %%
from langchain.llms import Cohere, OpenAI

llm = Cohere()
llm.invoke('How many hours of sleep is needed')
# Out:
# <ipython-input-3-33b637b68b53>:3: LangChainDeprecationWarning: The class `Cohere` was deprecated in LangChain 0.1.14 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-cohere package and should be used instead. To use it run `pip install -U :class:`~langchain-cohere` and import as `from :class:`~langchain_cohere import Cohere``.
#   llm = Cohere()
# ...

# %%
prompt = '''
 Analyse if the below ones are  a positive or negative sentiment?
1. "I had a good time with my friend"
2. "It was a horrible situation"

'''
llm.invoke(prompt)
# Out:
# ' 1. Positive \n\n2. Negative '

# %%
#A usecase for Data Analysts
import pandas as pd

log_messages = [
     "INFO: Server started successfully",
    "WARNING: Low disk space",
    "CRITICAL: Database connection failed",
    "CRITICAL: Security breach detected",
    "INFO: New feature released",

]

df = pd.DataFrame(log_messages,columns=['Message'])
df.head()
# Out:
#                                 Message
# 0     INFO: Server started successfully
# 1               WARNING: Low disk space
# 2  CRITICAL: Database connection failed
# 3    CRITICAL: Security breach detected
# 4            INFO: New feature released

# %%
df['Sentiment'] = df.Message.apply(lambda message: llm.invoke(f"Classify the severity of this log message make give output as CRITICAL if the message is critical: {message}"))
df.head()
# Out:
#                                 Message  \
# 0     INFO: Server started successfully
# 1               WARNING: Low disk space
# 2  CRITICAL: Database connection failed
# 3    CRITICAL: Security breach detected
# 4            INFO: New feature released
#
#                                            Sentiment
# 0   The log message "INFO: Server started success...
# 1   The severity of the log message "WARNING: Low...
# 2     The severity of the log message is: CRITICAL.
# 3   The log message "CRITICAL: Security breach de...
# 4   The provided log message, "INFO: New feature ...
